# %% [markdown]
# <center><h1> Week 7 - Functions </h1></center>
#
# 0) Write a code to find if the sum of divisors of a number lesser than itself, equals that number.
#
# 0) Given the dictionary of grades of students below, calculate their GPA.
#
# d = {"Sam": ]'A',' A-', 'C-', 'B'],
# "Nick": ['C', 'C-', 'B-', 'C+'],
# "Kevin": ['B', 'A', 'C', 'B'],
# "Joe": ['A','A','A','A'],
# "Brandon": ['A', 'C','A-','B+']
# }
#
# 1) Write a function that takes a list of floating point numbers, and another floating point number and adds the number to all the ones in the list.
#
# 2) Write a function that takes a tuple, representing m and c in the equation y=mx+c and returns the x-intercept, if there is no x-intercept it returns False.
#
# 3) Write a function that takes a string and returns the reversed string.
#
# 4) Write a function which takes two strings and returns True if they are anagrams and False otherwise.
#
# 5) Write a function that takes input as list of 4-lists consisting of [name,age,height,weight] and returns a dictionary "names":[list of names], "ages":[list of ages], "heights":[list of heights], "weights":[list of weights]
#
# 6) Write a function that takes a tuple of two floats and returns the position of that the point with those coordinates in the plane. If it lies in a quadrant return "1st quadrant", "2nd quadrant" etc. If it lies on an axis it returns "x-axis" or "y-axis". If it is the origin, return "origin"
#
# 7) Write a function that takes two tuples as pair of points and returns the equation of the line joining them as a string.
#
# 8) Write a function that takes a list of floats and returns a list with the greatest integer lesser than(math.floor()) the absolute values of each.
#
# 9) Write a function that takes a list of lists and returns the flattened list, that is, a list containing all the items of the lists of the input list.
#
# 10) Write a function that takes a list of integers representing the coefficients of a polynomial and a integer. Return a tuple with the first entry as the degree of the polynomial and the second entry as True or False depending on whether the number is a zero of the polynomial or not. [This question avoids floats for simplicity]
#
#
# 11) Write a function which takes a list of floating point numbers and returns a dictionary
# {"mean": mean-value of the elements
#  "median": ---
#  "mode":---
#  "variance":---
#  "max":---
#  "min":---}
#
# 12) Write a function that takes a list of strings and returns the string sentence formed by concatenating the elements of the list with spaces in between.
#
# 13) Write a function that takes an angle in degrees as a integer, and returns the following dictionary:
#
# {"radians": radian value of the angle
#  "sin": sine of the angle
#  "cos": cosine of the angle
#  "tan": tangent of the angle
#  }
#
# 14) Write a function that takes a pair of integers as a tuple and returns a list of all multiples of 3 between them. If the numbers are equal then it returns 1 or 0 depending on whether it is a multiple of 3 or not.
#
# 15) Write a function that takes two lists of floats of the same length and returns the euclidean distance between them. If there's a problem with the lists, it returns False.
#
# 16) Write a function that takes the length of sides of a triangle and returns the area of the triangle which recall is given by:
#
# Area = $\sqrt{ p ( p − a ) ( p − b ) ( p − c )}$ where $p = \frac{a+b+c}{2}$. If the expression in the square root is negative return the string "Invalid Triangle"
#
# 17) Write a function that takes a triple of floats consisting of the dimensions of a cuboid as a tuple and returns a tuple pair consisting of the volume and list of three areas of the faces.
#
# 18) Write a function which takes an integer number of seconds and returns it as the string "x days, y hours, z minutes and w seconds".
#
# 19) Write a function that takes the movement of a particle as a list of strings of the type: ["10.1 units forward", "3.6 units backward","1.9 units backward", "7.8 units forward"] and returns the final displacement from the position of starting as a string eg "12.9 units forward" for the above example.
#
# 20) Write a function that takes a character and a list of strings and returns a list of True or False depending on whether the character is in the string at each index or not.
