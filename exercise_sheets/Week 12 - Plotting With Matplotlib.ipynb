# %% [markdown]
# <center><h1> Week 12 - Plotting With Matplotlib </h1></center>
#
# <h3> Graphs, Histograms, Pie Charts, Scatter Plots </h3>
#
# <h2> Inclass Groupwork </h2>
#
# 1) Plot the graph of $x^2+x-1$ on interval [-10, 10]. (take $x$-values at 0.01 increments or alternatively use `np.linspace()`
# with 2000 points)
#
# 2) Sort the list below using the `sort()` function. Plot the value of the number against its index in the sorted list.
#
# 32, 30, 16,  9, 37, 17, 46, 19, 42,  0, 15, 16,  0, 31, 29, 35, 48, 40, 16, 25
#
# 3) In the file `ages.txt` is a list of comma separated values of ages of a population. Plot the frequency (number of people) of each age (y-axis) against age(x-axis).
#
# 4) Plot $\sin(x)$, $\sin(x)/x$ and $e^{-x}\sin(x)$ on the same graph/axes but in different colors and different line styles: continuous, dashed, dotted. Use a legend to indicate which curve corresponds to which function.
#
# 5) Within the same figure, plot four function on four different axes. Functions: $x\log(|x|)$, $\frac{1}{1+x^2}$, $\frac{e^x-e^{-x}}{e^x+e^{-x}}$, $\frac{x}{\sqrt{1+2x^2}}$
#
# 6) Create a dot graph for the functions: $x, x^2, x^3$ on the interval [1,5] with 20 sample points in between. Use blue squares for $x^3$, red diamonds for $x^2$ and green circles for $x$. Your graph should look like the one below:
#
# ![](image0.png)
#
#     import matplotlib.pyplot as plt
#     x=np.linspace(1,5,20)
#     plt.plot(x,x,'go')
#     plt.plot(x,x**2,'rd')
#     plt.plot(x,x**3,'bs')
#
# 7) The salaries of employees of a company are listed in the file `salary.txt`. Plot a frequency histogram with salaries in jumps of 10k. For each 10k bracket, plot the number of people in that bracket.
#
#
# 8) From the file `ice_cream_sales.txt` draw a scatter plot of ice-cream sales vs temperature.
#
# 9) From the file `Weather.txt` draw a scatter plot with classes for temperature vs humidity for Boston and San Francisco.
#
# 10) Plot the following renewable energy consumption on a pie chart:
#
# Biomass (48%)
# Hydroelectric (42%)
# Geothermal (5%)
# Wind (4%)
# Solar (1%)
#
# Your chart should look something like this:
#
# ![](image4.png)
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#     energy = ["Biomass (48%)","Hydroelectric (42%)","Geothermal (5%)","Wind (4%)","Solar (1%)"]
#     labels = [x.split()[0] for x in energy]
#     sizes = [float(x.split("(")[1].rstrip("%)")) for x in energy]
#     fig1, ax1 = plt.subplots()
#     ax1.pie(sizes, labels=labels)
#     plt.show()

# %% [markdown]
# <h2> Homework </h2>
#
# 1) Recall that a number is said to be prime if it is not divisible by any number smaller than itself except 1. Let $\pi(x)$ denote the number of primes smaller than a given number. The prime number theorem says that the graphs of the functions $\pi(x)$ and $x/\ln(x)$ get very close to each other as $x$ increases. In this question, you should plot both these functions on the range [2,10^6] and observe the prime number theorem.
#
# 2) Use a for loop to create the following plot:
# ![](image1.png)
#
#     c = 1
#     for i in range(-6,5,3):
#         plt.plot([i,i],[c,-c],'g')
#         plt.plot([i,i+3],[-c,-c],'g')
#         c = c*-1
#
#
# 3) Use a for loop to create interlocked semicircles as shown below:
#
# ![](image2.png)
#
# These are interlocked semicircles of radius varying from 1 to 7. You may use a different color, but a single arc must be of the same color.
#
#     for i in range(1,8,1):
#         x = np.linspace(0,i,100*i)
#         if i%2 == 1:
#             plt.plot(x,np.sqrt(i**2-x**2),'c')
#             plt.plot(x,-np.sqrt(i**2-x**2),'c')
#
#         else:
#             plt.plot(-x,np.sqrt(i**2-x**2),'r')
#             plt.plot(-x,-np.sqrt(i**2-x**2),'r')
#
# 4) Using the file `ages.txt` to plot a frequency histogram of ages of a given population.
#
# 5) The GDP of USA, China and Japan for the years 2010-2018 are given in the file `GDP.txt`. Plot these in a bar chart.
#
# 6) The file `global_warming_NASA.txt` represents the change in global surface temperature relative to 1951-1980 average temperatures. Plot the second column (under No_smoothing heading) versus year.
#
# 7) Plot the following data on a horizontal bar chart:
#
# Excuses for being late to class:
#
# Reason - Frequency(for one semester)
#
# My dog hid my glasses - 14
#
# It was too dark, I thought it was still nighttime - 5
#
# I forgot to set my alarm - 26
#
# I thought it was Saturday - 8
#
# I had no clean pants to wear - 12
#
# Your bar chart should look something like this:
#
# ![](image7.png)
#
#     import matplotlib.pyplot as plt; plt.rcdefaults()
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     exc = ( 'My dog hid my glasses','It was too dark, I thought it was still nighttime','I forgot to set my alarm',
#        'I thought it was Saturday','I had no clean pants to wear')
#     y_pos = np.arange(len(exc))
#     freq = [14,5,26,8,12]
#
#     plt.barh(y_pos, freq, align='center', alpha=0.5)
#     plt.yticks(y_pos, exc)
#     plt.xlabel('Frequency')
#     plt.title('Excuses for being late to class')
#     plt.show()
#
# 8) Below is the list of continents by percentage of world population. Plot it as a pie chart.
#
# Asia 59.69%
# Africa 16.36%
# Europe 9.94%
# North America 7.79%
# South America 5.68%
# Oceania 0.54%
#
# 9) Plot the graph of the function $r=\theta$ for $\theta$ in [0,2$\pi$] in polar coordinates. Your graph should look something like this:
#
# ![](image6.png)
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     theta = np.arange(0, 2*math.pi, 0.01)
#     r = theta
#
#     ax = plt.subplot(projection='polar')
#     ax.plot(theta, r)
#     ax.grid(True)
#
#     plt.show()
#
#
#
# 10) Boston daily weather information(temp, rain, snow), for the year 2018, is given in the file `BostonWeather.csv` and also in Excel format in the file `BostonWeather.xlsx`. Plot a line graph for rainfall vs day number(1 to 365), a histogram of rainfall against week(sum up the daily rainfall to get weekly rainfall) and a histogram for rainfall against month(sum up the daily rainfall to get monthly rainfall). You may use whichever format you prefer.
